# %% [markdown]
# <a href="https://colab.research.google.com/github/dmsukhanov/std/blob/main/linear_regression_Boston_Exploration_ipynb%22%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Boston Prices Dataset

# %%
import numpy as np
from numpy.linalg import inv
from matplotlib import pyplot as plt
x = np.array(boston_df['"RM"'])
y = np.array(boston_df['Price'])
x = x.reshape((len(x), 1))

#Y = ax+B
#a = np.random.sample(1)
#b = np.random.sample(1)
#a=0
#b=0
#a,b

#y**2 - (ax+b)**2 ->0

# linear least squares
b = inv(x.T.dot(x)).dot(x.T).dot(y)
#rint(b)
# predict using coefficients
yhat = x.dot(b)
print(yhat)
#yhat = a*x+b
#q = np.sum((yhat-y)**2)
#print(q)
# plot data and predictions
plt.scatter(x, y)
plt.plot(x, yhat, color='red')
plt.show()
# Out:
# [24.02077888 23.45816292 26.24932262 25.5661461  26.11049531 23.49104307
#  21.9639426  22.54847867 20.5720161  21.9347158  23.2974155  21.95298255
#  21.51458051 21.73378153 22.27082404 21.31364623 21.68263462 21.8835689
#  19.93267978 20.92273774 20.34916173 21.79223514 22.43887816 21.23692588
#  21.64244777 20.45510889 21.23692588 22.09180987 23.72851085 24.38246057
#  20.87159084 22.18314363 21.73743488 20.82775063 22.27082404 21.67532792
#  21.33921969 21.37209984 21.79588849 24.09384589 25.66113321 24.73318221
#  22.53751862 22.69095933 22.17218358 20.75833697 21.13828541 22.02970291
#  19.72443881 20.46606894 21.78492844 22.3402377  23.78696445 21.9127957
#  21.51092716 26.48313705 23.3193356  24.90123633 22.44983821 21.65340782
#  20.97388465 21.79588849 23.58603018 24.7039554  25.95340124 22.97957402
#  21.14193876 21.47439365 20.43684214 21.4999671  23.44354952 21.77762173
#  22.15757018 22.81517325 22.91746706 22.96496061 22.93938716 22.43157146
# ...

# %%
import numpy as np
from numpy.linalg import inv
from matplotlib import pyplot as plt
x = np.array(boston_df['"RM"'])
y = np.array(boston_df['Price'])
x1 = x.reshape((len(x), 1))

m = len(x)

def calc_cost(z,x,y):
  m = len(x)
  predict = x.dot(z)
  cost = (1/2*m)*np.sum((predict-y)**2)
  return cost

def grad(x,y,z,learning_rate=0.000001,iterations=1000):
  m = len(x)
  
  cost_hist = np.zeros([iterations,1])
  z_hist = np.zeros((iterations,m))

  for i in range(iterations):
    prediction = np.dot(x,z)
    z=z-(1/m)*learning_rate*(x.T.dot((prediction-y)))
    z_hist[i,:] = z.T
    cost_hist[i] = calc_cost(z,x,y)

  return z, cost_hist,z_hist

lr =0.000001
n_iter = 1000

#z = np.random.randn(506,1) 
z=np.zeros([m,1])
z, cost_hist,z_hist = grad(x,y,z,lr,n_iter)

w = z_hist[-1]
#print(cost_hist)
#print(z_hist[-1])
print(x)
print(z[-1,:])
qwe = x*z
print(qwe)
print('z0:          {:0.3f},\nz1:          {:0.3f}'.format(z[0][0],z[1][0]))
#print('Final cost/MSE:  {:0.3f}'.format(cost_hist[-1],[0]))

# plot data and predictions
plt.scatter(x, y)
plt.plot(x, x*w, color='red')
plt.show()
# Out:
# [6.575 6.421 7.185 6.998 7.147 6.43  6.012 6.172 5.631 6.004 6.377 6.009
#  5.889 5.949 6.096 5.834 5.935 5.99  5.456 5.727 5.57  5.965 6.142 5.813
#  5.924 5.599 5.813 6.047 6.495 6.674 5.713 6.072 5.95  5.701 6.096 5.933
#  5.841 5.85  5.966 6.595 7.024 6.77  6.169 6.211 6.069 5.682 5.786 6.03
#  5.399 5.602 5.963 6.115 6.511 5.998 5.888 7.249 6.383 6.816 6.145 5.927
#  5.741 5.966 6.456 6.762 7.104 6.29  5.787 5.878 5.594 5.885 6.417 5.961
#  6.065 6.245 6.273 6.286 6.279 6.14  6.232 5.874 6.727 6.619 6.302 6.167
#  6.389 6.63  6.015 6.121 7.007 7.079 6.417 6.405 6.442 6.211 6.249 6.625
#  6.163 8.069 7.82  7.416 6.727 6.781 6.405 6.137 6.167 5.851 5.836 6.127
#  6.474 6.229 6.195 6.715 5.913 6.092 6.254 5.928 6.176 6.021 5.872 5.731
#  5.87  6.004 5.961 5.856 5.879 5.986 5.613 5.693 6.431 5.637 6.458 6.326
#  6.372 5.822 5.757 6.335 5.942 6.454 5.857 6.151 6.174 5.019 5.403 5.468
#  4.903 6.13  5.628 4.926 5.186 5.597 6.122 5.404 5.012 5.709 6.129 6.152
# ...

# %%
import numpy as np
import pandas as pd
from sklearn import datasets
from numpy.linalg import inv
from matplotlib import pyplot as plt

boston_dataset = datasets.load_boston()
file_path = boston_dataset['filename']
boston_df = pd.read_csv(file_path, sep='\t', delimiter= '\,', header = 1)
boston_df['Price']=boston_dataset['target']
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   if __name__ == '__main__':

# %%
boston_df.columns
# Out:
# Index(['"CRIM"', '"ZN"', '"INDUS"', '"CHAS"', '"NOX"', '"RM"', '"AGE"',
#        '"DIS"', '"RAD"', '"TAX"', '"PTRATIO"', '"B"', '"LSTAT"', '"MEDV"',
#        'Price'],
#       dtype='object')

# %%
# import numpy as np
# import pandas as pd
# from sklearn import datasets
# from numpy.linalg import inv
# from matplotlib import pyplot as plt


#x = np.array(boston_df[['"RM"','"INDUS"']])
x = np.array(boston_df['"RM"'])
y = np.array(boston_df['Price'])

x = x.reshape((len(x), 1))
y = y.reshape((len(y), 1))


# plt.plot(x,y)
# plt.xlabel("$x$", fontsize=18)
# plt.ylabel("$y$", rotation=0, fontsize=18)
# _ =plt.axis([0,2,0,15])

def  cal_cost(theta,x,y):

    m = len(y)
    
    predictions = x.dot(theta)
    cost = (1/2*m) * np.sum(np.square(predictions-y))
    return cost

def gradient_descent(x,y,theta,learning_rate=0.01,iterations=100):

    m = len(y)
    cost_history = np.zeros(iterations)
    theta_history = np.zeros((iterations,2))
    for it in range(iterations):
        
        prediction = np.dot(x,theta)
        
        theta = theta - (1/m)*learning_rate*( x.T.dot((prediction - y)))
        theta_history[it,:] =theta.T
        cost_history[it]  = cal_cost(theta,x,y)
        #print(theta[0])
        
    return theta, cost_history, theta_history

lr =0.01
n_iter = 1000

theta = np.random.randn(2,1)

x_b = np.c_[np.ones((len(x),1)),x]
#x_b = x
theta,cost_history,theta_history = gradient_descent(x_b,y,theta,lr,n_iter)

print(x_b)

print('Theta0:          {:0.4f},\nTheta1:          {:0.4f}'.format(theta[0][0],theta[1][0]))
print('Final cost/MSE:  {:0.2f}'.format(cost_history[-1]))

print(theta)


def plot_GD(n_iter,lr,ax,ax1=None):

     _ = ax.plot(x,y,'y.')
     theta = np.random.randn(2,1)

     tr =0.5
     cost_history = np.zeros(n_iter)
     for i in range(n_iter):
        pred_prev = x_b.dot(theta)
        theta,h,_ = gradient_descent(x_b,y,theta,lr,1)
        pred = x_b.dot(theta)

        cost_history[i] = h[0]

        _ = ax.plot(x,pred,'r-',alpha=tr)

fig = plt.figure(figsize=(10,5))

it_lr =[(2000,0.001),(500,0.01)]
count =0
for n_iter, lr in it_lr:
    count += 1
    
    ax = fig.add_subplot(1, 2, count)
    #count += 1
   
    ax.set_title("lr:{}".format(lr))
    plot_GD(n_iter,lr,ax)
# Out:
# [[1.    6.575]
#  [1.    6.421]
#  [1.    7.185]
#  ...
#  [1.    6.976]
#  [1.    6.794]
#  [1.    6.03 ]]
# Theta0:          -4.8752,
# Theta1:          4.4181
# Final cost/MSE:  6981911.51
# [[-4.87520153]
#  [ 4.41811802]]
