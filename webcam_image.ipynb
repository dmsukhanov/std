# %%
# %matplotlib inline

import cv2
import matplotlib.pyplot as plt
from IPython import display
import os
import numpy as np

# %%
vc = cv2.VideoCapture(0)

plt.ion()

is_capturing, frame = vc.read()
#frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)  
#frame = cv2.resize(frame, (28,28))

webcam_preview = plt.imshow(frame)  


directory = r'/Users/dmitryi/Documents/GitHub/data/images/2'     #новая директория для сохранения
os.chdir(directory)                                            #меняю директорию

# Filename 
filename = '2.jpeg'
cv2.imwrite(filename, frame) 

vc.release()

# %%
#Открываю, то что сохранил
img = cv2.imread('/Users/dmitryi/Documents/GitHub/data/images/9/9.jpeg')
 
#img = cv2.cvtColor(img, cv2.IMREAD_COLOR)     
    
webcam_preview = plt.imshow(img)  
len(img.shape)
# Out:
# 3
