# %%
# %matplotlib inline

import cv2
import matplotlib.pyplot as plt
from IPython import display
import os

# %%
vc = cv2.VideoCapture(0)

plt.ion()

is_capturing, frame = vc.read()
frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)    # makes the blues image look real colored
webcam_preview = plt.imshow(frame)  

directory = r'/Users/dmitryi/Documents/GitHub/data/images'     #новая директория для сохранения
os.chdir(directory)                                            #меняю директорию

# Filename 
filename = '0.png'
cv2.imwrite(filename, frame) 

vc.release()

# %%
vc = cv2.VideoCapture(0)

plt.ion()

is_capturing, frame = vc.read()
frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)    # makes the blues image look real colored
webcam_preview = plt.imshow(frame)  

vc.release()

# %%
#Открываю, то что сохранил
img = cv2.imread('/Users/dmitryi/Documents/GitHub/data/images/0.png')
 
img = cv2.cvtColor(img, cv2.IMREAD_COLOR)     
    
webcam_preview = plt.imshow(img)
